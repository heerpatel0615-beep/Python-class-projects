# %%
#FUNDAMENTAL BOOSTERS

# %%
print("Welcome to Interactive Personal Data Collector")
# Out:
# Welcome to Interactive Personal Data Collector

# %%
name = input("Please enter your name: ")

age = int(input("Please enter your age: "))

height = float(input("Please enter your height in meters: "))

fav_number = int(input("Please enter your favourite number: "))
# Out:
# Please enter your name:  Alice
# Please enter your age:  25
# Please enter your height in meters:  1.68
# Please enter your favourite number:  7

# %%
print("Thank you! Here is the information we collected: ")
# Out:
# Thank you! Here is the information we collected:

# %%
print("Name:", name, "Name Type:", type(name), "Memory Address:", id(name))
print("Age:", age, "Age type:", type(age), "Memory Address:", id(age))
print("Height:", height, "Height type:", type(height), "Memory Address:", id(height))
print("Favourite Number:", fav_number, "Favourite Number Type:", type(fav_number), "Memory Address:", id(fav_number))
# Out:
# Name: Alice Name Type: <class 'str'> Memory Address: 2565642540240
# Age: 25 Age type: <class 'int'> Memory Address: 140719247173288
# Height: 1.68 Height type: <class 'float'> Memory Address: 2565596336080
# Favourite Number: 7 Favourite Number Type: <class 'int'> Memory Address: 140719247172712

# %%
#to find out your birth year follow the given steps

# %%
age = int(input("Please enter your age: "))
current_year = int(input("Please enter the current year: "))
birth_year = current_year - age
anynumber = int(input("enter any number: "))
fav_number = int(input("enter a number you like: "))
multiplication_of_numbers= fav_number * anynumber
print("Your birth year:", birth_year)
print("multiplication of numbers: ",multiplication_of_numbers)
# Out:
# Please enter your age:  25
# Please enter the current year:  2026
# enter any number:  103
# enter a number you like:  7
# Your birth year: 2001
# multiplication of numbers:  721

# %%
print("Thank you for using the Personal Data Collector")
# Out:
# Thank you for using the Personal Data Collector
